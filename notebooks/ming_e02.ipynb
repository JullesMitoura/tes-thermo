# %% [markdown]
# ### `tes-thermo`
# ---
#
# In this notebook, we will use `tes-thermo` to calculate the equilibrium compositions for the steam methane reforming (SMR) process.
#
# Version 0.1.1 of `tes-thermo` allows the user to leverage the `thermo` library to retrieve information about the components and also enables the addition of new components.
#
# First, import the Component and Gibbs classes. Then, specify the components to be considered.

# %%
# %pip install -qU tes-thermo

# %%
# %cd ..
# Out:
# /Users/mitoura/Desktop/Repositories/tes-thermo

# %%
from tes_thermo.utils import Component
from tes_thermo.gibbs import Gibbs
import numpy as np

components = ['water','carbon monoxide', 'carbon dioxide', 'hydrogen', 'methane']
comps = Component(components)
comps = comps.get_components()

# %% [markdown]
# In `new_components`, the components to be added are defined. In this case, the user must specify all the thermodynamic properties of the component as well as the polynomial used to calculate $C_p$.
#
# For this example, the following polynomial was used:
#
# $$C_p(T) = R \times \left( 1.702 + 0.009081T - 0.000002164T^2 \right)$$
#
# where $T$ is the temperature in Kelvin and $ C_p $ is the heat capacity in J/(mol·K).
#
# The components listed in `components` will be instantiated using the `Chemical` class from the `thermo` library.

# %%
gibbs = Gibbs(components=comps,
              equation='Ideal Gas')

res = gibbs.solve_gibbs(T=1200, T_unit= 'K',
                         P=1, P_unit='bar',
                         initial=np.array([1,  0,  0,  0, 0.5]))
# Out:
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Initializing Gibbs class...
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Components created as Chemical from the thermo library: ['water', 'carbon monoxide', 'carbon dioxide', 'hydrogen', 'methane']
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Manually defined components: []
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Inhibited components: []
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Equation of state: Ideal Gas
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Starting Gibbs minimization problem resolution
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Temperature: 1200.0 K, Pressure: 100000.0 Pa.
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Total inhibited components: 0
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Phases identified - Solids: 0, Gases: 5
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Element balance constraints added for 3 species
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Starting optimization problem resolution
# [np.float64(-217718.73838899672), np.float64(-241808.25878361973), np.float64(-435817.8316102301), np.float64(-22724.499021260166), np.float64(-14635.12496939786)]
# 2026-01-06 22:49:29 - tes_thermo.gibbs.gibbs - INFO - Optimal solution found successfully

# %% [markdown]
# Note that the `Component` class takes both `components` and `new_components` as arguments. The `get_components` method already returns the required structure to instantiate the `Gibbs` class.
#
# With this information, the `solve_gibbs` method returns the equilibrium compositions at temperature $T$ and pressure $P$, given the initial compositions specified by `initial`.

# %%
res
# Out:
# {'Temperature (K)': 1200.0,
#  'Pressure (bar)': 1.0,
#  'Water': 0.4064468417410891,
#  'Carbon monoxide': 0.40591703674338014,
#  'Carbon dioxide': 0.09383307073081329,
#  'Hydrogen': 1.5930233582741717,
#  'Methane': 0.000269912306444366}
