# %% [markdown]
# ### `tes-thermo`
# ---

# %%
# %cd ..
# Out:
# /Users/mitoura/Desktop/Repositories/tes-thermo

# %%
from tes_thermo.thermo_agent import ThermoAgent
from tes_thermo.utils import VectorSearch
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
load_dotenv(override=True)

# Create OpenAI client
openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Model names
llm_model_name = "gpt-4o-mini"  # or your preferred model
embedding_model_name = "text-embedding-3-small"  # or your preferred embedding model

# %%
# Create vector search (optional, for RAG)
vsearch = VectorSearch.from_documents(
    document_paths=[],  # replace with your document paths (pdf only...)
    openai_client=openai_client,
    model_name=embedding_model_name
)

# Create ThermoAgent
agent = ThermoAgent(
    openai_client=openai_client,
    llm_model_name=llm_model_name,
    embedding_model_name=embedding_model_name,
    vsearch=vsearch
)
# Out:
# No documents were processed. Creating empty index.

# %%
prompt = """
Simulate the methane steam reforming process considering CH4, CO, CO2, H2, and H2O.
The process should be simulated at 1200 K and 1 bar.
Assume a feed consisting of 0.5 mole of CH4 and 1 moles of H2O.
Present the results in a table and discuss how I can improve the dynamic formation process and the solutions involved in the process.
"""
res = agent.chat(prompt=prompt)
print(res['output'])
# Out:
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Initializing Gibbs class...
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Components created as Chemical from the thermo library: ['CH4', 'H2O', 'CO', 'CO2', 'H2']
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Manually defined components: []
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Inhibited components: []
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Equation of state: Peng-Robinson
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Starting Gibbs minimization problem resolution
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Temperature: 1200.0 K, Pressure: 100000.0 Pa.
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Total inhibited components: 0
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Phases identified - Solids: 0, Gases: 5
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Element balance constraints added for 3 species
# 2026-01-06 23:40:31 - tes_thermo.gibbs.gibbs - INFO - Starting optimization problem resolution
# [np.float64(-24604.30782139392), np.float64(-217718.73838899672), np.float64(-241808.25878361973), np.float64(-435817.8316102301), np.float64(-22724.499021260166)]
# 2026-01-06 23:40:32 - tes_thermo.gibbs.gibbs - INFO - Optimal solution found successfully
# The simulation results for the methane steam reforming process at 1200 K and 1 bar, given an initial feed of 0.5 moles of CH4 and 1 mole of H2O, are presented in the table below:
#
# | Component | Initial Moles | Equilibrium Moles | Change in Moles |
# |-----------|---------------|-------------------|------------------|
# | CH4       | 0.5           | 0.00073           | -0.49927         |
# | H2O       | 1.0           | 0.40687           | +0.40687         |
# | CO        | 0.0           | 0.40541           | +0.40541         |
# | CO2       | 0.0           | 0.09387           | +0.09387         |
# | H2        | 0.0           | 1.59168           | +1.59168         |
#
# ### Discussion on Improving the Dynamic Formation Process
# To enhance the efficiency of the methane steam reforming process and to improve the dynamic formation of products (H2, CO, CO2), consider the following strategies:
#
# 1. **Temperature Control:**
#    - Higher temperatures generally favor endothermic reactions like reforming. However, temperature management is critical; excessive heat might encourage side reactions or catalyst deactivation. Maintaining optimal temperature can enhance conversion rates.
#
# 2. **Pressure Optimization:**
#    - The reforming process can benefit from pressures above atmospheric levels (1 bar). Increasing pressure often pushes equilibrium towards the right side, favoring product formation (H2, CO) in accordance with Le Chatelier's principle.
#
# 3. **Catalyst Selection:**
#    - Use highly active catalysts (like nickel-based catalysts) to increase reaction rates and yield. Additionally, catalysts with good thermal stability can endure higher temperatures without breaking down.
#
# 4. **Reactor Design:**
#    - Implementing advanced reactor designs, such as packed bed or fluidized bed reactors, can enhance mass transfer and improve contact between reactants and the catalyst.
#
# 5. **Use of Steam:**
#    - The steam-to-carbon ratio should be optimized. A higher steam-to-carbon ratio can shift equilibrium towards product formation but may also lead to increased energy requirements; thus careful balancing is necessary.
#
# 6. **Optimize Feed Composition:**
#    - The initial feed composition can be adjusted according to the desired product yield. Experimental trials to find an optimal ratio can help maximize H2 output.
#
# 7. **Incorporate Reactant Recycling:**
#    - In a closed-loop system, unreacted CH4 or CO can be collected and recycled back into the reactor, increasing overall efficiency.
#
# 8. **Use of Inert Gases:**
#    - Inert gases can be introduced to stabilize the system and improve selectivity towards the desired products.
#
# By integrating these strategies, the efficiency and effectiveness of the methane steam reforming process can be significantly enhanced, allowing for greater yield of hydrogen and minimized production of undesired by-products.
